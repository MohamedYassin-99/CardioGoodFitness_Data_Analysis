# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/hamoy/Desktop/CardioGoodFitness.csv")
print(df.head(5))
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# ## checking null values and data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
## No null and duplicates in the data
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.describe().T
# Out:
#            count          mean           std      min       25%      50%  \
# Age        180.0     28.788889      6.943498     18.0     24.00     26.0
# Education  180.0     15.572222      1.617055     12.0     14.00     16.0
# Usage      180.0      3.455556      1.084797      2.0      3.00      3.0
# Fitness    180.0      3.311111      0.958869      1.0      3.00      3.0
# Income     180.0  53719.577778  16506.684226  29562.0  44058.75  50596.5
# Miles      180.0    103.194444     51.863605     21.0     66.00     94.0
#
#                 75%       max
# Age           33.00      50.0
# Education     16.00      21.0
# Usage          4.00       7.0
# Fitness        4.00       5.0
# Income     58668.00  104581.0
# Miles        114.75     360.0

# %%
## average age in the data : 28.78   - the range of the age from 18-50.
# Mean Education is 15.6 years. Range is between 12 - 21 years.
# average Usage : 3 times per week      the range: 2:7 times per week.
# Mean fitness is 3.3. Range is between 1- 5. 
# Mean income is 53'720 $. Range is between 29'562 $ - 104'581 $.
# Mean miles is 103.2. Range is between 21 - 360 miles.

# %% [markdown]
# # Visualize The data

# %%
sns.histplot(df,x='Product')
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Count'>

# %%
cat_cols = [col for col in df.columns if str(df[col].dtype) in ["int64",'category', 'object', 'bool']]
for col in cat_cols[2:6]:
    print(sns.countplot(data=df, x=col, hue='Product'))
    plt.show()
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)
# AxesSubplot(0.125,0.11;0.775x0.77)
# AxesSubplot(0.125,0.11;0.775x0.77)
# AxesSubplot(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## TM195  possesses most of the statistics for customers

# %% [markdown]
# ## Summarize categorical variables

# %%
def cat_summary(dataframe, col_name, plot=False):
    print(pd.DataFrame({col_name: dataframe[col_name].value_counts(),
                       'Ratio': round(100*(dataframe[col_name].value_counts()) / len(dataframe), 2)}))
    
    if plot:
        plt.figure(figsize=(8, 5))
        sns.countplot(x=col_name, data=dataframe)
        plt.show()
        
    print('######################################################################\n')
for col in cat_cols:
    print(cat_summary(df, col, plot=True))
# Out:
#        Product  Ratio
# TM195       80  44.44
# TM498       60  33.33
# TM798       40  22.22
# ######################################################################
#
# None
#     Age  Ratio
# 25   25  13.89
# 23   18  10.00
# 24   12   6.67
# 26   12   6.67
# 28    9   5.00
# 35    8   4.44
# 33    8   4.44
# 30    7   3.89
# 38    7   3.89
# 21    7   3.89
# 22    7   3.89
# 27    7   3.89
# 31    6   3.33
# 34    6   3.33
# 29    6   3.33
# 20    5   2.78
# 40    5   2.78
# 32    4   2.22
# 19    4   2.22
# 48    2   1.11
# 37    2   1.11
# 45    2   1.11
# 47    2   1.11
# 46    1   0.56
# 50    1   0.56
# 18    1   0.56
# 44    1   0.56
# 43    1   0.56
# 41    1   0.56
# 39    1   0.56
# 36    1   0.56
# 42    1   0.56
# ######################################################################
#
# None
#         Gender  Ratio
# Male       104  57.78
# Female      76  42.22
# ######################################################################
#
# None
#     Education  Ratio
# 16         85  47.22
# 14         55  30.56
# 18         23  12.78
# 15          5   2.78
# 13          5   2.78
# 12          3   1.67
# 21          3   1.67
# 20          1   0.56
# ######################################################################
#
# None
#            MaritalStatus  Ratio
# Partnered            107  59.44
# Single                73  40.56
# ######################################################################
#
# None
#    Usage  Ratio
# 3     69  38.33
# 4     52  28.89
# 2     33  18.33
# 5     17   9.44
# 6      7   3.89
# 7      2   1.11
# ######################################################################
#
# None
#    Fitness  Ratio
# 3       97  53.89
# 5       31  17.22
# 2       26  14.44
# 4       24  13.33
# 1        2   1.11
# ######################################################################
#
# None
#        Income  Ratio
# 45480      14   7.78
# 52302       9   5.00
# 46617       8   4.44
# 54576       8   4.44
# 53439       8   4.44
# ...       ...    ...
# 65220       1   0.56
# 55713       1   0.56
# 68220       1   0.56
# 30699       1   0.56
# 95508       1   0.56
#
# [62 rows x 2 columns]
# ######################################################################
#
# None
#      Miles  Ratio
# 85      27  15.00
# 95      12   6.67
# 66      10   5.56
# 75      10   5.56
# 47       9   5.00
# 106      9   5.00
# 94       8   4.44
# 113      8   4.44
# 53       7   3.89
# 100      7   3.89
# 180      6   3.33
# 200      6   3.33
# 56       6   3.33
# 64       6   3.33
# 127      5   2.78
# 160      5   2.78
# 42       4   2.22
# 150      4   2.22
# 38       3   1.67
# 74       3   1.67
# 170      3   1.67
# 120      3   1.67
# 103      3   1.67
# 132      2   1.11
# 141      2   1.11
# 280      1   0.56
# 260      1   0.56
# 300      1   0.56
# 240      1   0.56
# 112      1   0.56
# 212      1   0.56
# 80       1   0.56
# 140      1   0.56
# 21       1   0.56
# 169      1   0.56
# 188      1   0.56
# 360      1   0.56
# ######################################################################
#
# None
